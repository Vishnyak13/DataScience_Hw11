# %%
# Base libs and modules import

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LeakyReLU, BatchNormalization

# %%
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices()[2])
# Out:
# name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4954920064
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3061164086609299860
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"

# %%
# Distribution of the dataset into training and test samples

# %%
(x_train, label_train), (x_test, label_test) = fashion_mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# Normalizatoin dataset

# %%
x_train = x_train.reshape((60000, 28, 28, 1))
x_train = x_train.astype("float32") / 255

x_test = x_test.reshape((10000, 28, 28, 1))
x_test = x_test.astype("float32") / 255

# %%
# Intro train dataset

# %%
label_name = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
plt.figure(figsize=(15, 15), facecolor='HoneyDew')
for i in range(20):
    plt.subplot(5,4,i+1)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xticks([])
    plt.yticks([])
    plt.colorbar()
    plt.xlabel(label_name[label_train[i]])

# %%
# Create neural network model

# %%
model = keras.Sequential([
    
    keras.layers.Conv2D(64, (5,5), padding="same", activation="relu", input_shape=(28, 28, 1)),
    keras.layers.MaxPooling2D((2, 2)),

    keras.layers.Conv2D(128, (5,5), padding="same", activation="relu"),
    keras.layers.MaxPooling2D((2, 2)),

    keras.layers.Conv2D(128, (5,5), padding="same", activation="relu"),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.BatchNormalization(),
    
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation="relu"),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(32, activation="sigmoid"),
    keras.layers.Dense(10, activation="softmax")
])

# %%
# Compile model NN

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        1664
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       204928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 128)         409728
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 3, 3, 128)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                73792
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 693,034
# Trainable params: 692,778
# Non-trainable params: 256
# _________________________________________________________________

# %%
# Learning model NN

# %%
batch_size = 512
epochs = 70
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history=model.fit(
    x_train,
    label_train,
    validation_split=0.1,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=early_stop
)
# Out:
# Epoch 1/70
# 106/106 [==============================] - 4s 42ms/step - loss: 1.5881 - accuracy: 0.5204 - val_loss: 2.1899 - val_accuracy: 0.1467
# Epoch 2/70
# 106/106 [==============================] - 4s 38ms/step - loss: 1.1107 - accuracy: 0.7801 - val_loss: 1.6907 - val_accuracy: 0.5703
# Epoch 3/70
# 106/106 [==============================] - 4s 38ms/step - loss: 0.9252 - accuracy: 0.8393 - val_loss: 1.1864 - val_accuracy: 0.8325
# Epoch 4/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.8078 - accuracy: 0.8629 - val_loss: 0.8498 - val_accuracy: 0.8675
# Epoch 5/70
# 106/106 [==============================] - 4s 38ms/step - loss: 0.7216 - accuracy: 0.8756 - val_loss: 0.6858 - val_accuracy: 0.8748
# Epoch 6/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.6514 - accuracy: 0.8848 - val_loss: 0.5995 - val_accuracy: 0.8832
# Epoch 7/70
# 106/106 [==============================] - 4s 38ms/step - loss: 0.5933 - accuracy: 0.8925 - val_loss: 0.5509 - val_accuracy: 0.8868
# Epoch 8/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.5488 - accuracy: 0.8987 - val_loss: 0.5108 - val_accuracy: 0.8957
# Epoch 9/70
# 106/106 [==============================] - 4s 38ms/step - loss: 0.5076 - accuracy: 0.9049 - val_loss: 0.4748 - val_accuracy: 0.8965
# Epoch 10/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.4723 - accuracy: 0.9103 - val_loss: 0.4481 - val_accuracy: 0.9035
# Epoch 11/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.4424 - accuracy: 0.9141 - val_loss: 0.4353 - val_accuracy: 0.9025
# Epoch 12/70
# 106/106 [==============================] - 4s 40ms/step - loss: 0.4139 - accuracy: 0.9191 - val_loss: 0.4069 - val_accuracy: 0.9055
# Epoch 13/70
# 106/106 [==============================] - 4s 40ms/step - loss: 0.3897 - accuracy: 0.9222 - val_loss: 0.3899 - val_accuracy: 0.9113
# Epoch 14/70
# 106/106 [==============================] - 4s 38ms/step - loss: 0.3683 - accuracy: 0.9247 - val_loss: 0.3746 - val_accuracy: 0.9140
# Epoch 15/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.3462 - accuracy: 0.9287 - val_loss: 0.3585 - val_accuracy: 0.9128
# Epoch 16/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.3279 - accuracy: 0.9316 - val_loss: 0.3525 - val_accuracy: 0.9130
# Epoch 17/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.3090 - accuracy: 0.9367 - val_loss: 0.3354 - val_accuracy: 0.9178
# Epoch 18/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.2913 - accuracy: 0.9396 - val_loss: 0.3264 - val_accuracy: 0.9148
# Epoch 19/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.2739 - accuracy: 0.9441 - val_loss: 0.3180 - val_accuracy: 0.9190
# Epoch 20/70
# 106/106 [==============================] - 4s 40ms/step - loss: 0.2625 - accuracy: 0.9453 - val_loss: 0.3067 - val_accuracy: 0.9212
# Epoch 21/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.2467 - accuracy: 0.9495 - val_loss: 0.3028 - val_accuracy: 0.9202
# Epoch 22/70
# 106/106 [==============================] - 4s 41ms/step - loss: 0.2332 - accuracy: 0.9514 - val_loss: 0.2942 - val_accuracy: 0.9235
# Epoch 23/70
# 106/106 [==============================] - 4s 41ms/step - loss: 0.2217 - accuracy: 0.9541 - val_loss: 0.2803 - val_accuracy: 0.9237
# Epoch 24/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.2092 - accuracy: 0.9577 - val_loss: 0.3093 - val_accuracy: 0.9125
# Epoch 25/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.1977 - accuracy: 0.9601 - val_loss: 0.2708 - val_accuracy: 0.9255
# Epoch 26/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.1868 - accuracy: 0.9622 - val_loss: 0.2785 - val_accuracy: 0.9230
# Epoch 27/70
# 106/106 [==============================] - 4s 40ms/step - loss: 0.1794 - accuracy: 0.9639 - val_loss: 0.2679 - val_accuracy: 0.9260
# Epoch 28/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.1670 - accuracy: 0.9676 - val_loss: 0.2799 - val_accuracy: 0.9217
# Epoch 29/70
# 106/106 [==============================] - 4s 38ms/step - loss: 0.1612 - accuracy: 0.9674 - val_loss: 0.3266 - val_accuracy: 0.9057
# Epoch 30/70
# 106/106 [==============================] - 4s 38ms/step - loss: 0.1487 - accuracy: 0.9713 - val_loss: 0.2630 - val_accuracy: 0.9257
# Epoch 31/70
# 106/106 [==============================] - 4s 38ms/step - loss: 0.1408 - accuracy: 0.9731 - val_loss: 0.2625 - val_accuracy: 0.9227
# Epoch 32/70
# 106/106 [==============================] - 4s 40ms/step - loss: 0.1342 - accuracy: 0.9745 - val_loss: 0.2531 - val_accuracy: 0.9282
# Epoch 33/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.1228 - accuracy: 0.9782 - val_loss: 0.2726 - val_accuracy: 0.9208
# Epoch 34/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.1186 - accuracy: 0.9784 - val_loss: 0.2772 - val_accuracy: 0.9220
# Epoch 35/70
# 106/106 [==============================] - 4s 38ms/step - loss: 0.1124 - accuracy: 0.9797 - val_loss: 0.2594 - val_accuracy: 0.9260
# Epoch 36/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.1038 - accuracy: 0.9820 - val_loss: 0.2614 - val_accuracy: 0.9223
# Epoch 37/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.1012 - accuracy: 0.9820 - val_loss: 0.2514 - val_accuracy: 0.9265
# Epoch 38/70
# 106/106 [==============================] - 4s 38ms/step - loss: 0.0932 - accuracy: 0.9842 - val_loss: 0.2542 - val_accuracy: 0.9267
# Epoch 39/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.0854 - accuracy: 0.9865 - val_loss: 0.2525 - val_accuracy: 0.9263
# Epoch 40/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.0813 - accuracy: 0.9873 - val_loss: 0.2499 - val_accuracy: 0.9288
# Epoch 41/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.0781 - accuracy: 0.9875 - val_loss: 0.2529 - val_accuracy: 0.9262
# Epoch 42/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.0721 - accuracy: 0.9891 - val_loss: 0.2595 - val_accuracy: 0.9250
# Epoch 43/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.0659 - accuracy: 0.9904 - val_loss: 0.2653 - val_accuracy: 0.9247
# Epoch 44/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.0643 - accuracy: 0.9905 - val_loss: 0.2580 - val_accuracy: 0.9242
# Epoch 45/70
# 106/106 [==============================] - 4s 39ms/step - loss: 0.0645 - accuracy: 0.9894 - val_loss: 0.2557 - val_accuracy: 0.9242

# %%
# Model results

# %%
results = model.evaluate(x_test, label_test)
print(f'Model Loss: {round(results[0], 3)} \nModel Accuracy: {round(results[1], 3)}')
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2569 - accuracy: 0.9282
# Model Loss: 0.257
# Model Accuracy: 0.928

# %%
# Plot train and validation data

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 9))


axes[0].set_title('Train metrics Loss & Val_Loss')
axes[0].plot(history.history['loss'], label='Loss', color='SteelBlue')
axes[0].plot(history.history['val_loss'], label='Val_loss', marker='o', linestyle='--', color='SteelBlue')
axes[0].legend()

axes[1].set_title('Train metrics Accuracy & Val_Accuracy')
axes[1].plot(history.history['accuracy'], label='Accuracy', color='DarkOrange')
axes[1].plot(history.history['val_accuracy'], label='Val_Accuracy', marker='o', linestyle='--', color='DarkOrange')
axes[1].legend()

plt.show()

# %%
# Predict model NN

# %%
predict=model.predict(x_test)

# %%
random_indexes = np.random.choice(len(x_test), size=20, replace=False)

plt.figure(figsize=(15, 15), facecolor='HoneyDew')

for i in range(len(random_indexes)):
    
    index = random_indexes[i]
    
    pred_label = label_name[np.argmax(predict[index])]
    true_label = label_name[label_test[index]]
    
    if pred_label == true_label:
        color = "DarkBlue"
    else:
        color = "FireBrick"
    
    plt.subplot(5,4,i+1)
    plt.imshow(x_test[index], cmap=plt.cm.binary)
    plt.xticks([])
    plt.yticks([])
    plt.colorbar()
    
    plt.xlabel("{} [{}]".format(true_label, pred_label), color=color)

# %% [markdown]
# In the previous homework, the maximum accuracy achieved was 90% with an error rate of 39.2%. Currently, using a convolutional model, the maximum accuracy achieved is 92.8% with an error rate of 29.7%. Therefore, the increase in accuracy using a convolutional neural network is 2.8% with a decrease in error rate of 9.5%.
